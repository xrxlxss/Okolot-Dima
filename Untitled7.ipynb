# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize
from scipy.misc import derivative
import math

x_min, x_max = -1, 2

y_min, y_max = -1, 1

step = 0.01

x, y = np.meshgrid(np.arange(x_min, x_max, step),

                   np.arange(y_min, y_max, step))

eq1 = y + np.cos(x-1) -0.7

eq2 = 2*x+np.sin(y) -2

fig, ax = plt.subplots(figsize=(10, 10))

ax.contour(x, y, eq1, levels=[0], colors='red')
ax.contour(x, y, eq2, levels=[0], colors='blue')
ax.set_xlim([x_min, x_max])

ax.set_ylim([y_min, y_max])

ax.set_xlabel('x')

ax.set_ylabel('y')

ax.set_title('Графік системи рівнянь')

plt.grid(True)

plt.show()

# %%
import numpy as np
from scipy import optimize
from scipy.misc import derivative
import math

x0 = 1.25
y0 = -0.4
delta = 0.1

def f1(y):
    return -0.5*(math.sin(y))  + 1
def f2 (x):
    return - (math.cos(x -1))+0.7

def iter (x,y,e):
    xn = x
    yn = y
    xn1 = f2(x)
    yn1 = f1(y)
    n = 1
    while ((abs(xn1-xn)>=e) & (abs(yn1-yn) >=e)):
        xn = xn1
        yn = yn1
        xn1 = f2(yn)
        yn1 = f1(xn)
        n += 1
    print ('Simple iteration:')
    print ('x=', xn, '\ny=',yn,'\nThe amount of iteration = ',n)
iter(x0,y0,0.0001)

def f3(x):
    return math.sin(x[1]) +2*x[0]-2  , math.cos(x[0]-1 ) + x[1] -0.7
s = optimize.root(f3, [0.,0.], method = 'hybr')
print ('Chek',s.x)
# Out:
# Simple iteration:
# x= -0.28971496030948685
# y= 1.1431655591807337
# The amount of iteration =  6
# Chek [ 1.14288476 -0.28980933]
